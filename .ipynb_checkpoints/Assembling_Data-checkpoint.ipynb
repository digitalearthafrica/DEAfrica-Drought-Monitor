# %% [markdown]
# # Assembling and ranking data for the DE Africa drought monitoring
#
# * **Products used:**

# %% [raw]
# **Keywords** :index:`data used;`

# %% [markdown]
# ## Background
# Ranking of drought monitoring variables prior to principal component analysis as per Guillory et al. 2023.

# %% [markdown]
# ## Description
# Loading and ranking data for drought monitoring.
#
# 1. Load and rank standardised precipitation index (SPI) using CHIRPS.
# 2. Load and rank soil moisture.
# 3. Load and rank monthly NDVI.
# 4. Load and rank reference ET.
#
# ***

# %% [markdown]
# ## Getting started
#
# Provide any particular instructions that the user might need, e.g. To run this analysis, run all the cells in the notebook, starting with the "Load packages" cell.

# %% [markdown]
# ### Load packages
# Import Python packages that are used for the analysis.
#
# Use standard import commands; some are shown below.
# Begin with any `iPython` magic commands, followed by standard Python packages, then any additional functionality you need from the `Tools` package.

# %%
# %matplotlib inline

import datacube
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# ### Connect to the datacube
#
# Connect to the datacube so we can access DE Africa data.
# The `app` parameter is a unique name for the analysis which is based on the notebook file name.

# %%
dc = datacube.Datacube(app='DroughtData')

# %% [markdown]
# ### Analysis parameters
#
# We will focus on a part of Zambia for this demonstration. We've loaded the Zambia .gpkg from [GADM](https://gadm.org/index.html) into our `../data` directory.

# %%
zmb = gpd.read_file('data/Zambia/gadm41_ZMB.gpkg', layer = 'ADM_ADM_1')

zmb
# Out:
#       GID_1 GID_0 COUNTRY         NAME_1      VARNAME_1 NL_NAME_1    TYPE_1  \
# 0   ZMB.1_1   ZMB  Zambia        Central    Broken Hill        NA  Province
# 1   ZMB.2_1   ZMB  Zambia     Copperbelt        Western        NA  Province
# 2   ZMB.3_1   ZMB  Zambia        Eastern   Fort Jameson        NA  Province
# 3   ZMB.4_1   ZMB  Zambia        Luapula  Fort Rosebery        NA  Province
# 4   ZMB.5_1   ZMB  Zambia         Lusaka             NA        NA  Province
# 5   ZMB.6_1   ZMB  Zambia       Muchinga             NA        NA  Province
# 6   ZMB.7_1   ZMB  Zambia  North-Western             NA        NA  Province
# 7   ZMB.8_1   ZMB  Zambia       Northern             NA        NA  Province
# 8   ZMB.9_1   ZMB  Zambia       Southern             NA        NA  Province
# 9  ZMB.10_1   ZMB  Zambia        Western    Barotseland        NA  Province
#
#   ENGTYPE_1 CC_1 HASC_1  ISO_1  \
# 0  Province   NA  ZM.CE  ZM-02
# 1  Province   NA  ZM.CO  ZM-08
# 2  Province   NA  ZM.EA  ZM-03
# 3  Province   NA  ZM.LP  ZM-04
# 4  Province   NA  ZM.LS  ZM-09
# 5  Province   NA  ZM.MU  ZM-10
# 6  Province   NA  ZM.NW  ZM-06
# 7  Province   NA  ZM.NO  ZM-05
# 8  Province   NA  ZM.SO  ZM-07
# 9  Province   NA  ZM.WE  ZM-01
#
#                                             geometry
# 0  MULTIPOLYGON (((27.24544 -15.72238, 27.24094 -...
# 1  MULTIPOLYGON (((28.64984 -12.83038, 28.65274 -...
# 2  MULTIPOLYGON (((30.78534 -14.78948, 30.77554 -...
# 3  MULTIPOLYGON (((29.57224 -12.19608, 29.56986 -...
# 4  MULTIPOLYGON (((28.90991 -15.9837, 28.90808 -1...
# 5  MULTIPOLYGON (((29.81347 -12.14948, 29.81345 -...
# 6  MULTIPOLYGON (((23.53308 -12.9953, 23.9469 -12...
# 7  MULTIPOLYGON (((29.81334 -11.41218, 29.90984 -...
# 8  MULTIPOLYGON (((25.89364 -17.97668, 25.88814 -...
# 9  MULTIPOLYGON (((24.95344 -17.54978, 24.94784 -...

# %% [markdown]
# We can see that there are 10 provinces. We will focus our analysis on the province of Luapula.

# %%
lpl = zmb[zmb.NAME_1=="Luapula"]

lpl.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Heading 1
# Use headings to break up key steps/stages of the notebook.
#
# Use markdown text for detailed, descriptive text explaining what the code below does and why it is needed.
#
# > **Note:** Use this markdown format (sparingly) to draw particular attention to an important point or caveat

# %%
# Use code comments for low-level documentation of code
a = 1

# %% [markdown]
# ### Subheading 1
# Use subheadings to break up steps within a single section.

# %%
# Use code comments for low-level documentation of code
b = 2

# %% [markdown]
# ## Heading 2
# Use markdown text for detailed, descriptive text explaining what the code below does and why it is needed.

# %%
# Use code comments for low-level documentation of code
c = 3

# %% [markdown]
# ***
#
# ## Additional information
#
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Africa data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** If you need assistance, please post a question on the [Open Data Cube Slack channel](http://slack.opendatacube.org/) or on the [GIS Stack Exchange](https://gis.stackexchange.com/questions/ask?tags=open-data-cube) using the `open-data-cube` tag (you can view previously asked questions [here](https://gis.stackexchange.com/questions/tagged/open-data-cube)).
# If you would like to report an issue with this notebook, you can file one on [Github](https://github.com/digitalearthafrica/deafrica-sandbox-notebooks).
#
# **Compatible datacube version:**

# %%
print(datacube.__version__)
# Out:
# 1.8.4.dev52+g07bc51a5

# %% [markdown]
# **Last Tested:**

# %%
from datetime import datetime
datetime.today().strftime('%Y-%m-%d')
# Out:
# '2021-03-02'
