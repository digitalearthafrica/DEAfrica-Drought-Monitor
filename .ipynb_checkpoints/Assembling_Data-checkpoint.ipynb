# %% [markdown]
# # Assembling and ranking data for the DE Africa drought monitoring
#
# * **Products used:**

# %% [raw]
# **Keywords** :index:`data used;`

# %% [markdown]
# ## Background
# Ranking of drought monitoring variables prior to principal component analysis as per Guillory et al. 2023.

# %% [markdown]
# ## Description
# Loading and ranking data for drought monitoring.
#
# 1. Load and rank standardised precipitation index (SPI) using CHIRPS.
# 2. Load and rank soil moisture.
# 3. Load and rank monthly NDVI.
# 4. Load and rank reference ET.
#
# ***

# %% [markdown]
# ## Getting started
#
# Provide any particular instructions that the user might need, e.g. To run this analysis, run all the cells in the notebook, starting with the "Load packages" cell.

# %% [markdown]
# ### Load packages
# Import Python packages that are used for the analysis.
#
# Use standard import commands; some are shown below.
# Begin with any `iPython` magic commands, followed by standard Python packages, then any additional functionality you need from the `Tools` package.

# %%
# %matplotlib inline

import datacube
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
import rioxarray
import matplotlib.pyplot as plt


from odc.geo import Geometry, CRS
from scipy import stats

# %% [markdown]
# ### Connect to the datacube
#
# Connect to the datacube so we can access DE Africa data.
# The `app` parameter is a unique name for the analysis which is based on the notebook file name.

# %%
dc = datacube.Datacube(app='DroughtData')

# %% [markdown]
# ### Analysis parameters
#
# We will focus on a part of Zambia for this demonstration. We've loaded the Zambia .gpkg from [GADM](https://gadm.org/index.html) into our `../data` directory.

# %%
zmb = gpd.read_file('data/Zambia/gadm41_ZMB.gpkg', layer = 'ADM_ADM_0')

zmb
# Out:
#   GID_0 COUNTRY                                           geometry
# 0   ZMB  Zambia  MULTIPOLYGON (((25.87834 -17.97218, 25.87034 -...

# %%
geom = Geometry(geom=zmb.geometry.union_all(), crs=zmb.crs)

# %% [markdown]
# ## Load CHIRPS Monthly Rainfall Data
#
# Load monthly rainfall.

# %%
time_m = ('1995', '2025')

# CHIRPS has a spatial resolution of ~5x5 km
resolution = (-5000, 5000)

#size of dask chunks
dask_chunks = dict(x=500,y=500, time = -1)

query = {'geopolygon': geom,
         'time': time_m,
         'output_crs': 'epsg:6933',
         'resolution': resolution,
         'measurements': ['rainfall'],
         'dask_chunks':dask_chunks
        }

ds_rf = dc.load(product='rainfall_chirps_monthly', **query)
ds_rf
# Out:
# <xarray.Dataset> Size: 82MB
# Dimensions:      (time: 368, y: 244, x: 227)
# Coordinates:
#   * time         (time) datetime64[ns] 3kB 1995-01-16T11:59:59.500000 ... 202...
#   * y            (y) float64 2kB -1.052e+06 -1.058e+06 ... -2.262e+06 -2.268e+06
#   * x            (x) float64 2kB 2.122e+06 2.128e+06 ... 3.248e+06 3.252e+06
#     spatial_ref  int32 4B 6933
# Data variables:
#     rainfall     (time, y, x) float32 82MB dask.array<chunksize=(368, 244, 227), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref

# %%
# 1. Normalize the existing messy timestamps to the 1st of each month
# We overwrite the 'time' coordinate with a cleaned version
ds_rf['time'] = pd.to_datetime([
    f"{y}-{m:02d}-01" for y, m in zip(ds_rf.time.dt.year.values, ds_rf.time.dt.month.values)
])

# 2. Create target range (this now matches the '01' format exactly)
full_time_range = pd.date_range(start='1995-01-01', end='2025-12-01', freq='MS')

# 3. Reindex - since they match perfectly now, this will keep your data
# and insert NaNs only for the 4 missing months.
ds_full = ds_rf.reindex(time=full_time_range)

# 4. Fill the 4 missing gaps
ds_interpolated = ds_full.interpolate_na(dim='time', method='linear')

# Optional: verify you now have 372 slices
print(len(ds_interpolated.time))
# Out:
# 372

# %%
ds_interpolated.compute()
# Out:
# <xarray.Dataset> Size: 82MB
# Dimensions:      (time: 372, y: 244, x: 227)
# Coordinates:
#   * time         (time) datetime64[ns] 3kB 1995-01-01 1995-02-01 ... 2025-12-01
#   * y            (y) float64 2kB -1.052e+06 -1.058e+06 ... -2.262e+06 -2.268e+06
#   * x            (x) float64 2kB 2.122e+06 2.128e+06 ... 3.248e+06 3.252e+06
#     spatial_ref  int32 4B 6933
# Data variables:
#     rainfall     (time, y, x) float32 82MB 115.2 119.2 116.5 ... 383.0 381.0
# Attributes:
#     crs:           EPSG:6933
#     grid_mapping:  spatial_ref

# %%
gdf = gpd.read_file('data/Zambia/gadm41_ZMB.gpkg', layer = 'ADM_ADM_1')

results = []

for index, row in gdf.iterrows():
    # 1. Mask the DataCube dataset to the current geometry
    # We use 'geometry' to clip the data to the specific polygon
    ds_feature = ds_interpolated.rio.clip([row.geometry], gdf.crs)
    
    # 2. Reduce spatially (Mean) to get a 1D timeseries
    # This collapses 'x' and 'y' dimensions
    ts_feature = ds_feature.rainfall.where(ds_feature.rainfall > -9999).mean(dim=['x', 'y']).compute()
    
    # 3. Convert to a Pandas Series or store in a list
    ts_series = ts_feature.to_series()
    ts_series.name = row['NAME_1']
    
    results.append(ts_series)

# Combine all timeseries into a single DataFrame
df_final = pd.concat(results, axis=1)

# %%
df_final
# Out:
#                Central  Copperbelt     Eastern     Luapula      Lusaka  \
# time
# 1995-01-01  154.149017  223.912506  227.569244  248.526413  137.061569
# 1995-02-01  193.848984  308.226868  154.876740  289.513641  137.170166
# 1995-03-01   58.367226  109.298569   98.685738  194.576431   44.433945
# 1995-04-01    7.920537    9.793279   12.268025   39.372005    8.365614
# 1995-05-01    2.437545    1.790497    3.039217    4.086508    2.322329
# ...                ...         ...         ...         ...         ...
# 2025-08-01    0.375310    0.312278    0.262998    0.496473    0.363081
# 2025-09-01    1.513265    1.524213    1.019324    3.843201    1.130087
# 2025-10-01    7.260383    8.118386    6.863963   17.414698    5.073830
# 2025-11-01  139.536758  165.668839  201.730164  117.669785  101.656853
# 2025-12-01  234.922012  258.162872  304.358978  196.749191  202.999573
#
#               Muchinga  North-Western    Northern    Southern     Western
# time
# 1995-01-01  272.679932     180.486145  293.264862  101.129982  101.187393
# 1995-02-01  242.293655     246.173203  289.317444  127.172142  223.318390
# 1995-03-01  162.961731     118.222000  255.837372   40.486637   88.655449
# 1995-04-01   19.556852      14.941639   38.405800    8.792447   18.246914
# 1995-05-01    5.171213       2.716148    6.047428    2.194712    3.146805
# ...                ...            ...         ...         ...         ...
# 2025-08-01    0.325278       0.695694    0.465959    0.153643    0.264679
# 2025-09-01    1.180800       6.991456    3.464504    2.056783    4.013654
# 2025-10-01    8.579893      24.266310   17.181805   10.432342   15.623535
# 2025-11-01  155.454514     103.773956  123.728149   85.420509   80.668610
# 2025-12-01  246.428558     242.172699  205.310120  201.549347  254.279678
#
# [372 rows x 10 columns]

# %%
print(f"Max rainfall: {df_final.max().max()}")
print(f"Min rainfall: {df_final.min().min()}")
print(f"Any zeros?: { (df_final == 0).any().any() }")
# Out:
# Max rainfall: 431.80413818359375
# Min rainfall: 0.02065429836511612
# Any zeros?: False

# %%
def compute_spi_manual(series, scale=3):
    # 1. Rolling accumulation (n-month sum)
    # min_periods=scale ensures we don't calculate SPI for incomplete windows
    data = series.rolling(window=scale, min_periods=scale).sum().dropna()
    
    if data.empty:
        return pd.Series(np.nan, index=series.index)

    # 2. Fit Gamma distribution
    # shape (alpha), location (loc), and scale (beta)
    # We fix loc=0 as is standard for precipitation
    fit_shape, fit_loc, fit_scale = stats.gamma.fit(data, floc=0)
    
    # 3. Calculate the Cumulative Distribution Function (CDF) 
    gamma_cdf = stats.gamma.cdf(data, fit_shape, fit_loc, fit_scale)
    
    # 4. Transform to Inverse Normal (Standardize it)
    # This turns probabilities into Z-scores (SPI values)
    spi_values = stats.norm.ppf(gamma_cdf)
    
    # 5. Handle infinite values (occurs at extreme probabilities)
    spi_values = np.clip(spi_values, -3.0, 3.0)
    
    # Return matched to the original index
    return pd.Series(spi_values, index=data.index).reindex(series.index)

# Apply to your dataframe
df_spi_final = df_final.apply(compute_spi_manual, scale=3)

# Check the middle of the dataframe to confirm values exist
print("Sample SPI values:\n", df_spi_final.dropna().head())
# Out:
# Sample SPI values:
#               Central  Copperbelt   Eastern   Luapula    Lusaka  Muchinga  \
# time
# 1995-03-01  0.906504    1.069416  1.031298  1.170524  0.838787  1.263724
# 1995-04-01  0.584975    0.758609  0.584208  0.870281  0.481808  0.860478
# 1995-05-01 -0.147006    0.018791  0.078721  0.290235 -0.174910  0.295945
# 1995-06-01 -0.843945   -0.858535 -0.740548 -0.583770 -0.778167 -0.641493
# 1995-07-01 -1.207835   -1.322658 -1.141351 -1.360708 -1.165765 -1.102784
#
#             North-Western  Northern  Southern   Western
# time
# 1995-03-01       0.986360  1.318300  0.781746  0.987210
# 1995-04-01       0.688516  0.972563  0.488688  0.806209
# 1995-05-01       0.014154  0.444638 -0.181581  0.090457
# 1995-06-01      -0.882624 -0.590612 -0.759678 -0.640086
# 1995-07-01      -1.429926 -1.264519 -1.172422 -1.223812

# %% [markdown]
# ### Subheading 1
# Use subheadings to break up steps within a single section.

# %%
# Use code comments for low-level documentation of code
b = 2

# %% [markdown]
# ## Heading 2
# Use markdown text for detailed, descriptive text explaining what the code below does and why it is needed.

# %%
# Use code comments for low-level documentation of code
c = 3

# %% [markdown]
# ***
#
# ## Additional information
#
# **License:** The code in this notebook is licensed under the [Apache License, Version 2.0](https://www.apache.org/licenses/LICENSE-2.0).
# Digital Earth Africa data is licensed under the [Creative Commons by Attribution 4.0](https://creativecommons.org/licenses/by/4.0/) license.
#
# **Contact:** If you need assistance, please post a question on the [Open Data Cube Slack channel](http://slack.opendatacube.org/) or on the [GIS Stack Exchange](https://gis.stackexchange.com/questions/ask?tags=open-data-cube) using the `open-data-cube` tag (you can view previously asked questions [here](https://gis.stackexchange.com/questions/tagged/open-data-cube)).
# If you would like to report an issue with this notebook, you can file one on [Github](https://github.com/digitalearthafrica/deafrica-sandbox-notebooks).
#
# **Compatible datacube version:**

# %%
print(datacube.__version__)
# Out:
# 1.8.4.dev52+g07bc51a5

# %% [markdown]
# **Last Tested:**

# %%
from datetime import datetime
datetime.today().strftime('%Y-%m-%d')
# Out:
# '2021-03-02'
